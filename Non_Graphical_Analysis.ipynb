# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load the dataset (Assuming the file is 'aerofit_treadmill.csv')
aerofit = pd.read_csv('aerofit_treadmill.csv')

# %%
# Unique Attributes Analysis [cite: 58]
print("Unique values per column:\n", aerofit.nunique())
# Out:
# Unique values per column:
#  Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
# Value Counts for key categories [cite: 63, 67, 71, 75]
print("Product Purchased:\n", aerofit['Product'].value_counts())
# Out:
# Product Purchased:
#  Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
print("\nGender Distribution:\n", aerofit['Gender'].value_counts())
# Out:
# Gender Distribution:
#  Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
print("\nMarital Status:\n", aerofit['MaritalStatus'].value_counts())
# Out:
# Marital Status:
#  MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
print("\nFitness Level:\n", aerofit['Fitness'].value_counts())
# Out:
# Fitness Level:
#  Fitness
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: count, dtype: int64
